# %% [markdown]
# <center><span style="font-family:Comic Sans MS; color:navy "><h1>House Pricee:Advanced Regression Techniques</h1></span></center>

# %% [markdown]
# # <b>1 <span style='color:#94D4F6'>|</span> About DataSet</b>

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'> Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.</span>
# <center>
# <img src="https://storage.googleapis.com/kaggle-competitions/kaggle/5407/media/housesbanner.png", width="400",  height="300"/>
# </center>

# %% [markdown]
# # <b>2 <span style='color:#94D4F6'>|</span> Define the Problem</b>
# <span style='font-family:comic Sans MS; color:navy'>With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.</span>

# %% [markdown]
# # <b>3 <span style='color:#94D4F6'>|</span> Import Libraries</b>

# %%
import numpy as np #linear algebra
import pandas as pd # data processing

#for graphs, visuals, etc.
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import plotly.express as px

#Configure Visualization Defaults
# %matplotlib inline = show plots in Jupyter Notebook browser
# %matplotlib inline
plt.style.use('ggplot')
sns.set_style('white')

import cufflinks as cf
cf.go_offline()

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# outliers
from collections import Counter  ## used in droping outliers
# encoding categorical features
from sklearn.preprocessing import(
    StandardScaler,# standard scalar will scale data from (-3 to 3)
    LabelEncoder, # for label encoding categorical features
    OneHotEncoder, # used for onehot encoding categorical features
) 
# ML models
from sklearn.svm import SVR
from sklearn.model_selection import(
    train_test_split,# used to split the data into training and testing
    RandomizedSearchCV,# used for tuning the models parameters
    cross_val_score,
    
    
    
)
from scipy.stats import(
    uniform,
    randint,
    )
from sklearn.linear_model import (
    LinearRegression,
    Ridge,
    Lasso
)
# for printing a table
from prettytable import(
 PrettyTable,
 ALL,
 FRAME,
    )
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# /kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv
# /kaggle/input/house-prices-advanced-regression-techniques/data_description.txt
# /kaggle/input/house-prices-advanced-regression-techniques/train.csv
# /kaggle/input/house-prices-advanced-regression-techniques/test.csv

# %% [markdown]
# # <b>4 <span style='color:#94D4F6'>|</span> Import Data</b>

# %%
df = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/train.csv')
df_test = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/test.csv')

# %% [markdown]
# # <b>5 <span style='color:#94D4F6'>|</span> PreProcessing</b>
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>5.1 |</span></b> How data Look! </b></p></div>

# %%
# train Data
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# test Data
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'> Skip of Price which we will predict,all data is the same and we should do preProcessing on both of(df and df_test)</span>

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>5.2 |</span></b> Data Information </b></p></div>

# %%
## shape of the training dataset
print('shape of the training dataset:')
print('There are {} rows and {} columns in train dataset.'.format(df.shape[0],df.shape[1]))
# Out:
# shape of the training dataset:
# There are 1460 rows and 81 columns in train dataset.

# %%
# Data Columns
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>We have 80 Coulmns in our dataSet</span>

# %%
# DataFrame Informatin
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>In this dataset, we have columns with categorical data and empty data, which we need to modify to predict and train the data.</span>

# %%
df.describe().style.background_gradient(cmap ='summer')
# Out:
# <style type="text/css">
# #T_dd963_row0_col0, #T_dd963_row0_col1, #T_dd963_row0_col2, #T_dd963_row0_col4, #T_dd963_row0_col5, #T_dd963_row0_col15, #T_dd963_row0_col17, #T_dd963_row0_col18, #T_dd963_row0_col19, #T_dd963_row0_col20, #T_dd963_row0_col21, #T_dd963_row0_col22, #T_dd963_row0_col23, #T_dd963_row0_col24, #T_dd963_row0_col26, #T_dd963_row0_col27, #T_dd963_row0_col28, #T_dd963_row0_col29, #T_dd963_row0_col30, #T_dd963_row0_col31, #T_dd963_row0_col32, #T_dd963_row0_col33, #T_dd963_row0_col35, #T_dd963_row1_col36, #T_dd963_row3_col36, #T_dd963_row4_col36, #T_dd963_row5_col36, #T_dd963_row6_col7, #T_dd963_row6_col36, #T_dd963_row7_col0, #T_dd963_row7_col3, #T_dd963_row7_col6, #T_dd963_row7_col7, #T_dd963_row7_col8, #T_dd963_row7_col9, #T_dd963_row7_col10, #T_dd963_row7_col11, #T_dd963_row7_col12, #T_dd963_row7_col13, #T_dd963_row7_col14, #T_dd963_row7_col16, #T_dd963_row7_col25, #T_dd963_row7_col34, #T_dd963_row7_col36, #T_dd963_row7_col37 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_dd963_row0_col3, #T_dd963_row0_col37, #T_dd963_row1_col4, #T_dd963_row1_col5, #T_dd963_row1_col17, #T_dd963_row1_col18, #T_dd963_row1_col19, #T_dd963_row1_col20, #T_dd963_row1_col21, #T_dd963_row1_col22, #T_dd963_row1_col23, #T_dd963_row1_col24, #T_dd963_row1_col26, #T_dd963_row1_col31, #T_dd963_row1_col33, #T_dd963_row1_col34, #T_dd963_row1_col35, #T_dd963_row2_col2, #T_dd963_row2_col4, #T_dd963_row2_col5, #T_dd963_row2_col6, #T_dd963_row2_col7, #T_dd963_row2_col17, #T_dd963_row2_col18, #T_dd963_row2_col19, #T_dd963_row2_col20, #T_dd963_row2_col21, #T_dd963_row2_col22, #T_dd963_row2_col23, #T_dd963_row2_col24, #T_dd963_row2_col25, #T_dd963_row2_col26, #T_dd963_row2_col35, #T_dd963_row2_col36, #T_dd963_row3_col0, #T_dd963_row3_col1, #T_dd963_row3_col2, #T_dd963_row3_col3, #T_dd963_row3_col4, #T_dd963_row3_col5, #T_dd963_row3_col8, #T_dd963_row3_col9, #T_dd963_row3_col10, #T_dd963_row3_col11, #T_dd963_row3_col12, #T_dd963_row3_col13, #T_dd963_row3_col14, #T_dd963_row3_col15, #T_dd963_row3_col16, #T_dd963_row3_col17, #T_dd963_row3_col18, #T_dd963_row3_col19, #T_dd963_row3_col20, #T_dd963_row3_col21, #T_dd963_row3_col22, #T_dd963_row3_col23, #T_dd963_row3_col24, #T_dd963_row3_col26, #T_dd963_row3_col27, #T_dd963_row3_col28, #T_dd963_row3_col29, #T_dd963_row3_col30, #T_dd963_row3_col31, #T_dd963_row3_col32, #T_dd963_row3_col33, #T_dd963_row3_col34, #T_dd963_row3_col35, #T_dd963_row4_col1, #T_dd963_row4_col4, #T_dd963_row4_col5, #T_dd963_row4_col8, #T_dd963_row4_col9, #T_dd963_row4_col10, #T_dd963_row4_col14, #T_dd963_row4_col15, #T_dd963_row4_col17, #T_dd963_row4_col18, #T_dd963_row4_col19, #T_dd963_row4_col20, #T_dd963_row4_col21, #T_dd963_row4_col22, #T_dd963_row4_col23, #T_dd963_row4_col24, #T_dd963_row4_col26, #T_dd963_row4_col28, #T_dd963_row4_col29, #T_dd963_row4_col30, #T_dd963_row4_col31, #T_dd963_row4_col32, #T_dd963_row4_col33, #T_dd963_row4_col34, #T_dd963_row4_col35, #T_dd963_row5_col4, #T_dd963_row5_col5, #T_dd963_row5_col8, #T_dd963_row5_col10, #T_dd963_row5_col14, #T_dd963_row5_col15, #T_dd963_row5_col17, #T_dd963_row5_col18, #T_dd963_row5_col19, #T_dd963_row5_col20, #T_dd963_row5_col21, #T_dd963_row5_col22, #T_dd963_row5_col23, #T_dd963_row5_col24, #T_dd963_row5_col26, #T_dd963_row5_col28, #T_dd963_row5_col30, #T_dd963_row5_col31, #T_dd963_row5_col32, #T_dd963_row5_col33, #T_dd963_row5_col34, #T_dd963_row5_col35, #T_dd963_row6_col5, #T_dd963_row6_col10, #T_dd963_row6_col15, #T_dd963_row6_col17, #T_dd963_row6_col18, #T_dd963_row6_col19, #T_dd963_row6_col20, #T_dd963_row6_col21, #T_dd963_row6_col22, #T_dd963_row6_col23, #T_dd963_row6_col24, #T_dd963_row6_col26, #T_dd963_row6_col30, #T_dd963_row6_col31, #T_dd963_row6_col32, #T_dd963_row6_col33, #T_dd963_row6_col34, #T_dd963_row7_col17, #T_dd963_row7_col18, #T_dd963_row7_col19, #T_dd963_row7_col20, #T_dd963_row7_col22, #T_dd963_row7_col24, #T_dd963_row7_col26 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_dd963_row0_col6 {
#   background-color: #b8dc66;
#   color: #000000;
# }
# #T_dd963_row0_col7, #T_dd963_row0_col36 {
#   background-color: #b9dc66;
#   color: #000000;
# }
# #T_dd963_row0_col8 {
#   background-color: #e8f366;
#   color: #000000;
# }
# #T_dd963_row0_col9, #T_dd963_row0_col13 {
#   background-color: #42a066;
#   color: #f1f1f1;
# }
# #T_dd963_row0_col10, #T_dd963_row5_col7 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_dd963_row0_col11 {
#   background-color: #a0d066;
#   color: #000000;
# }
# #T_dd963_row0_col12 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_dd963_row0_col14 {
#   background-color: #b4da66;
#   color: #000000;
# }
# #T_dd963_row0_col16, #T_dd963_row2_col14, #T_dd963_row5_col16, #T_dd963_row5_col37, #T_dd963_row6_col12 {
#   background-color: #369a66;
#   color: #f1f1f1;
# }
# #T_dd963_row0_col25 {
#   background-color: #aed666;
#   color: #000000;
# }
# #T_dd963_row0_col34, #T_dd963_row4_col11 {
#   background-color: #188c66;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col0, #T_dd963_row5_col0 {
#   background-color: #80c066;
#   color: #000000;
# }
# #T_dd963_row1_col1 {
#   background-color: #068266;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col2, #T_dd963_row2_col3, #T_dd963_row2_col30, #T_dd963_row5_col2 {
#   background-color: #0a8466;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col3, #T_dd963_row2_col29, #T_dd963_row3_col37, #T_dd963_row6_col29 {
#   background-color: #0b8566;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col6, #T_dd963_row4_col7 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_dd963_row1_col7, #T_dd963_row5_col25 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_dd963_row1_col8, #T_dd963_row1_col28 {
#   background-color: #108866;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col9, #T_dd963_row2_col9 {
#   background-color: #148a66;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col10, #T_dd963_row1_col29, #T_dd963_row2_col15, #T_dd963_row2_col34, #T_dd963_row4_col2, #T_dd963_row6_col1 {
#   background-color: #088466;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col11, #T_dd963_row6_col13 {
#   background-color: #3e9e66;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col12, #T_dd963_row5_col13 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col13, #T_dd963_row2_col11 {
#   background-color: #309866;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col14, #T_dd963_row4_col37 {
#   background-color: #2b9566;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col15, #T_dd963_row6_col4, #T_dd963_row6_col35, #T_dd963_row7_col4, #T_dd963_row7_col5, #T_dd963_row7_col21, #T_dd963_row7_col35 {
#   background-color: #018066;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col16 {
#   background-color: #389c66;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col25, #T_dd963_row5_col6 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_dd963_row1_col27 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col30, #T_dd963_row2_col1, #T_dd963_row2_col13 {
#   background-color: #038166;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col32, #T_dd963_row7_col23 {
#   background-color: #028066;
#   color: #f1f1f1;
# }
# #T_dd963_row1_col37 {
#   background-color: #3c9e66;
#   color: #f1f1f1;
# }
# #T_dd963_row2_col0 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# #T_dd963_row2_col8, #T_dd963_row2_col10 {
#   background-color: #1c8e66;
#   color: #f1f1f1;
# }
# #T_dd963_row2_col12 {
#   background-color: #128866;
#   color: #f1f1f1;
# }
# #T_dd963_row2_col16, #T_dd963_row2_col32, #T_dd963_row5_col3 {
#   background-color: #098466;
#   color: #f1f1f1;
# }
# #T_dd963_row2_col27 {
#   background-color: #259266;
#   color: #f1f1f1;
# }
# #T_dd963_row2_col28 {
#   background-color: #158a66;
#   color: #f1f1f1;
# }
# #T_dd963_row2_col31, #T_dd963_row5_col1 {
#   background-color: #058266;
#   color: #f1f1f1;
# }
# #T_dd963_row2_col33, #T_dd963_row4_col3 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# #T_dd963_row2_col37, #T_dd963_row6_col8 {
#   background-color: #1a8c66;
#   color: #f1f1f1;
# }
# #T_dd963_row3_col6 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_dd963_row3_col7, #T_dd963_row4_col6, #T_dd963_row7_col27 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_dd963_row3_col25 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_dd963_row4_col0 {
#   background-color: #40a066;
#   color: #f1f1f1;
# }
# #T_dd963_row4_c

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>Although we don't have only numerical columns, we can get some mathematical specifications from the table below</span>

# %%
print('Number of numerical columns:',df.mean(numeric_only=True).count())
df.mean(numeric_only=True)# mean of numerical columns
# Out:
# Number of numerical columns: 38
# Id                  730.500000
# MSSubClass           56.897260
# LotFrontage          70.049958
# LotArea           10516.828082
# OverallQual           6.099315
# OverallCond           5.575342
# YearBuilt          1971.267808
# YearRemodAdd       1984.865753
# MasVnrArea          103.685262
# BsmtFinSF1          443.639726
# BsmtFinSF2           46.549315
# BsmtUnfSF           567.240411
# TotalBsmtSF        1057.429452
# 1stFlrSF           1162.626712
# 2ndFlrSF            346.992466
# LowQualFinSF          5.844521
# GrLivArea          1515.463699
# BsmtFullBath          0.425342
# BsmtHalfBath          0.057534
# FullBath              1.565068
# HalfBath              0.382877
# BedroomAbvGr          2.866438
# KitchenAbvGr          1.046575
# TotRmsAbvGrd          6.517808
# Fireplaces            0.613014
# GarageYrBlt        1978.506164
# GarageCars            1.767123
# GarageArea          472.980137
# WoodDeckSF           94.244521
# OpenPorchSF          46.660274
# EnclosedPorch        21.954110
# 3SsnPorch             3.409589
# ScreenPorch          15.060959
# PoolArea              2.758904
# MiscVal              43.489041
# MoSold                6.321918
# YrSold             2007.815753
# SalePrice        180921.195890
# dtype: float64

# %% [markdown]
# # <b>6 <span style='color:#94D4F6'>|</span>Exploratory Data Analysis</b>

# %%
# The theme and size and resolution of the plots
# figure size
plt.figure(figsize=(6,3))  
# background, color type
sns.set_theme(style="whitegrid", palette="muted")
sns.set_context('notebook', font_scale = 1.0, rc={"lines.linewidth": 1.5})
# font properties
plt.rcParams['font.family']='cursive'
plt.rcParams['font.stretch']='condensed'
plt.rcParams['font.style']='italic'
plt.rcParams['font.weight']='heavy'
plt.rcParams['font.size']=15
# resolution
plt.rcParams['figure.dpi'] = 120  # resolution

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>here,I just do some basic settings for graph.</span>

# %%
sns.boxplot(data = df,x='SalePrice',whis = 2.5,fliersize=2)
plt.title("House Price Distribution")
plt.xticks([0,100000,200000,300000,400000,500000,600000,700000],['0','100k','200k','300k','400k','500k','600k','700k'])
plt.show()

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see, the most sold price is in the range of 100k-200k</span>

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 15))
plt.subplots_adjust(left=0.1,    
                    bottom=0.1,
                    right=0.9,
                    top=0.9,)
fig.suptitle('Sale Price with 4 top correlated features')
axes[0,0].set_xticklabels(axes[0,0].get_xticklabels(), rotation=90)
axes[0,1].set_xticklabels(axes[0,1].get_xticklabels(), rotation=90)
axes[1,0].set_xticklabels(axes[1,0].get_xticklabels(), rotation=90)
axes[1,1].set_xticklabels(axes[1,1].get_xticklabels(), rotation=90)
# ---------------------------------------------------------
# OverallQual
sns.boxplot(ax=axes[0,0],data = df,x='OverallQual',y='SalePrice',whis=2.5,fliersize=2)
axes[0,0].set_yticklabels(['0','100k','200k','300k','400k','500k','600k','700k'])
axes[0,0].set_xlabel('Overall Quality')
axes[0,0].set_ylabel('Price')

# GrLivArea
sns.scatterplot(ax=axes[0,1],x='SalePrice', y='GrLivArea',data=df,hue='SalePrice')
axes[0,1].set_xticklabels(['0','100k','200k','300k','400k','500k','600k','700k'])
axes[0,1].set_xlabel('Price')
axes[0,1].set_ylabel('Being high above the ground')


# GarageCars
sns.boxplot(ax=axes[1,0],data = df,x='GarageCars',y='SalePrice',whis=2.5,fliersize=2)
axes[1,0].set_yticklabels(['0','100k','200k','300k','400k','500k','600k','700k'])
axes[1,0].set_xlabel('Number of Car')
axes[1,0].set_ylabel('Price')

# GarageArea
sns.scatterplot(ax=axes[1,1],x='SalePrice', y='GarageArea',data=df,hue='SalePrice')
axes[1,1].set_xticklabels(['0','100k','200k','300k','400k','500k','600k','700k'])
axes[1,1].set_xlabel('Price')
axes[1,1].set_ylabel('Garage area')

# Set the spacing between subplots
fig.subplots_adjust(wspace=0.3, hspace=0.2)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see, the Quality of the home is the top correlated feature in our data set which we showed in 10 categories by difrince in price, in the second graph we showed, if the Ground Area be big it has more price, and third part we can see the relation of GrageCars(How many cars can we put) and price and the last one we see the garage areas and the effect of that on house price. </span>

# %%
# Setting
fig, axes = plt.subplots(2, 2, figsize=(10, 15))
plt.subplots_adjust(left=0.1,bottom=0.1,right=0.9,top=0.9)
fig.suptitle('Sale Price with 4 top correlated features')
axes[0,0].set_xticklabels(axes[0,0].get_xticklabels(), rotation=90)
axes[0,1].set_xticklabels(axes[0,1].get_xticklabels(), rotation=90)
axes[1,0].set_xticklabels(axes[1,0].get_xticklabels(), rotation=90)
axes[1,1].set_xticklabels(axes[1,1].get_xticklabels(), rotation=90)
# YearBuilt
sns.scatterplot(ax=axes[0,0],x='SalePrice', y='YearBuilt',data=df,hue='YearBuilt')
axes[0,0].set_xticklabels(['0','100k','200k','300k','400k','500k','600k','700k'])
axes[0,0].set_xlabel('Price')
axes[0,0].set_ylabel('Year')
# FullBath
# FullBath: Full bathrooms above grade
sns.boxplot(ax=axes[0,1],data = df,x='FullBath',y='SalePrice',whis=2.5,fliersize=2)
axes[0,1].set_yticklabels(['0','100k','200k','300k','400k','500k','600k','700k'])
axes[0,1].set_xlabel('Number of bathroom')
axes[0,1].set_ylabel('Price')
# Total square feet of basement area
sns.scatterplot(ax=axes[1,0],x='SalePrice', y='TotalBsmtSF',data=df,hue='SalePrice')
axes[1,0].set_xticklabels(['0','100k','200k','300k','400k','500k','600k','700k'])
axes[1,0].set_xlabel('Price')
axes[1,0].set_ylabel('Underground Area')
# 1stFlrSF
sns.scatterplot(ax=axes[1,1],x='SalePrice', y='1stFlrSF',data=df,hue='SalePrice')
axes[1,1].set_xticklabels(['0','100k','200k','300k','400k','500k','600k','700k'])
axes[1,1].set_xlabel('Price')
axes[1,1].set_ylabel('First Floor Area')

# Set the spacing between subplots
fig.subplots_adjust(wspace=0.3, hspace=0.2)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see, The year the houses were built has a great impact on the price of the house, as you can see in the picture on the left and above, old houses are cheap and new houses have to be bought at a high price, and it is very clear that house construction has increased in recent years.</span>
#
# <span style='font-family:comic Sans MS; color:navy'> - The number of bathrooms that a house has also affects the price, so it can be said that the houses that have this convenience have a good price.</span>
#
# <span style='font-family:comic Sans MS; color:navy'> - And in the third graph, we have shown the relationship between the underground area of a house and its price, which very clearly tells us that a larger area costs more.</span>
#
# <span style='font-family:comic Sans MS; color:navy'> - The third and fourth graphs express the same issue, in the fourth graph we have shown that the larger the area of the first floor, the higher the price of the house.
# </span>

# %% [markdown]
# # <b>6 <span style='color:#94D4F6'>|</span> Featur Engineering</b>

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>6.1 |</span></b> Taking care of missing data </b></p></div>

# %%
# cols names which contains missing values
df.columns[df.isnull().sum() > 0]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>We have Null data in 19 columns</span>

# %%
# Show missing Value
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>missing values in each columns will be presented by white lines</span>

# %%
# Fill missing value by previous value
df.fillna(method='bfill',inplace=True)
# Or we can fill missing value by next value
df.fillna(method='ffill',inplace = True)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>We have two Option for fill the missing value one fill by befor value other fill by next value</span>

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see, we don't have any missing value now in our dataSet</span>

# %%
## cols names which contains missing values
df.columns[df.isnull().sum() > 0]
# Out:
# Index([], dtype='object')

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see,by this commend we don't have Null data</span>

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>6.2 |</span></b> Drop duplicate data </b></p></div>

# %%
## shows number of duplicated values in the dataset
print('Number of duplicated values in dataset: ', df.duplicated().sum())
# Out:
# Number of duplicated values in dataset:  0

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see,we don't have duplicate data in our dataSet</span>

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>6.3 |</span></b> Drop outliers in the data </b></p></div>

# %%
numeric_columns = [x for i,x in enumerate(df.select_dtypes(include=np.number).columns.tolist())
                   if(x!='SalePrice')] 
numeric_columns
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
def IQR_method (df,n,features):
    outlier_list = []
    for column in features:
        # 1st quartile (25%)
        Q1 = np.percentile(df[column], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(df[column],75)
        # Interquartile range (IQR)
        IQR = Q3 - Q1
        # outlier step
        outlier_step = 1.5 * IQR
        # Determining a list of indices of outliers
        outlier_list_column = df[(df[column] < Q1 - outlier_step) | (df[column] > Q3 + outlier_step )].index
        # appending the list of outliers
        outlier_list.extend(outlier_list_column)
    # selecting observations containing more than x outliers
    outlier_list = Counter(outlier_list)        
    multiple_outliers = list( k for k, v in outlier_list.items() if v > n)
    # Calculate the number of records below and above lower and above bound value respectively
    out1 = df[df[column] < Q1 - outlier_step]
    out2 = df[df[column] > Q3 + outlier_step]
    print('Total number of deleted outliers is:', out1.shape[0]+out2.shape[0])
        
        
    return multiple_outliers

# %%
## drop outliers using IQR_method
Outliers_IQR = IQR_method(df,1,numeric_columns)
# print(Outliers_IQR)
df = df.drop(Outliers_IQR, axis = 0).reset_index(drop=True)
# Out:
# Total number of deleted outliers is: 0

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>6.4 |</span></b> Feature selection </b></p></div>

# %%
# correlation matrix between numerical cols in the dataset.
fig, ax = plt.subplots(figsize=(38,38))
coer = df.corr()
sns.heatmap(coer, annot = True, ax=ax, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm', linewidths=3, linecolor='black')
plt.show()

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see, we have some unnecessary columns which we didn't need for Price Prediction or maybe have a weak correlation.</span>

# %%
df.corr()['SalePrice'].sort_values(ascending=False)[0:20]
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.351799
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# Name: SalePrice, dtype: float64

# %%
col_drops = ['Id', 'MSSubClass', 'BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath',
             'KitchenAbvGr', '3SsnPorch', 'MiscVal', 'ScreenPorch', 'PoolArea','YrSold'] ## cols to drop 
df.drop(col_drops,axis=1,inplace=True)

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>6.5 |</span></b> Label encoding of categorical data </b></p></div>

# %%
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
categorical_cols = set(df.columns).difference(set(numeric_cols))   
print(categorical_cols)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see, here we have some categorical columns now we want to change them to predict.</span>

# %%
## print all unique values in categorical columns
for i, x in enumerate(categorical_cols):  
    print(x, df[x].unique())

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>Below we have some columns with their Unique data which come to dataSet ones</span>

# %%
## drop this col since it has one value
df.drop(['Utilities'],axis=1,inplace=True)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>here we delete the data come ones</span>

# %%
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
categorical_cols = set(df.columns).difference(set(numeric_cols))

# %%
## names of columns that will label encoded
lecols = []  
for x in categorical_cols:
    lecols.append(x)
le = LabelEncoder() #imported
df[lecols] = df[lecols].apply(le.fit_transform) #fit data
df.head()

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>6.6 |</span></b> Feature Scaling </b></p></div>

# %%
# scalar for all numerical columns excluding target column
sc_X = StandardScaler()
# scalar for the target column
sc_y = StandardScaler()
# list of col  names that include numerical values
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
# list of all numeric cols excluding the target col
numeric_cols_x = [x for i,x in enumerate(numeric_cols) if(x!='SalePrice')]
# list includes target col name
numeric_cols_y = [x for i,x in enumerate(numeric_cols) if(x not in numeric_cols_x)]
df[numeric_cols_x] = sc_X.fit_transform(df[numeric_cols_x])
df[numeric_cols_y]= sc_y.fit_transform(df[numeric_cols_y])
df.head()

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>6.7 |</span></b> Define the independent and dependent variables </b></p></div>

# %%
X = df.iloc[:, :-1].values ## independent variables
y = df.iloc[:, -1].values  ## dependent variables

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>6.8 |</span></b> Splitting the dataset into training and testing </b></p></div>

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>splitting the dataset into 80% training and 20% testing</span>

# %% [markdown]
# # <b>7 <span style='color:#94D4F6'>|</span>The machine learning models</b>

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>7.1 |</span></b> Initial models test </b></p></div>

# %%
init_models = {
    'support vector linear' : SVR(kernel='linear'),
    'support vector kernel' : SVR(kernel= 'rbf'),
    'XGBOOST':XGBRegressor(),
    'Decision Tree' : DecisionTreeRegressor(),
    'Random Forest' : RandomForestRegressor(),
    'LGBM' : LGBMRegressor()
}
R2 = []
models_names = []
for i,(key,model) in enumerate(init_models.items()):
    model.fit(X_train,y_train)
    models_names.append(key)
    R2.append(np.mean(cross_val_score(model,X_train,y_train,cv=5)))
models_scores = pd.DataFrame({'model name':models_names,'R2 score':R2})
models_scores.head(7)

# %% [markdown]
# - **<mark style="background-color:#D1D96A;color:black;border-radius:5px;opacity:0.7">  plot cross validation R2 scores for the models   </mark>**

# %%
fig, ax = plt.subplots()
ax.set_xticklabels(ax.get_xticklabels(), rotation=70)
ax.set_title("models R2 score")
sns.barplot(data=models_scores, x='model name', y="R2 score")
plt.show()

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see, the LGBM model is the best and we use it for our final prediction and submission.</span>

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>7.2 |</span></b> Tuning the parameters of promising models </b></p></div>

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>In the below, we have some model which was better for prediction,  we should try to make them better and choose one of them.</span>

# %% [markdown]
# - **<mark style="background-color:#D1D96A;color:black;border-radius:5px;opacity:0.7">Random Forest </mark>**

# %%
# rf = RandomForestRegressor(random_state=0,n_estimators=10)
# param_grid = {
#     'max_features':['auto','sqrt'],
#     'max_depth':[int(x) for x in np.linspace(5,30,6)],
#     'min_samples_split':[2,5,10,15,100],
#     'min_samples_leaf':[1,2,5,10],
# }
# rf_cv = RandomizedSearchCV(rf,param_grid,n_iter = 40,refit = 'recall',
#                            scoring = 'neg_mean_squared_error',cv=5,verbose=2,random_state=42,n_jobs=-1)
# rf_cv.fit(X_train,y_train)

# %% [markdown]
# - **<mark style="background-color:#D1D96A;color:black;border-radius:5px;opacity:0.7"> XGBOOST </mark>**

# %%
# xgb = XGBRegressor()
# param_grid = {
#     'learning_rate':[0.0001,0.001,0.01,0.1,1],
#     'max_depth':range(3,21,3),
#     'gamma':[i/10.0 for i in range(0,5)],
#     'colsample_bytree':[i/10.0 for i in range(3,10)],
#     'reg_alpha':[1e-5, 1e-2, 0.1, 1, 10, 100],
#     'reg_lambda':[1e-5, 1e-2, 0.1, 1, 10, 100]
# }
# xgb_cv = RandomizedSearchCV(xgb,param_grid,n_iter=100, refit='recall',
#                            scoring = 'neg_mean_squared_error',verbose=2,random_state=42,n_jobs=-1)
# xgb_cv.fit(X_train,y_train)

# %% [markdown]
# - **<mark style="background-color:#D1D96A;color:black;border-radius:5px;opacity:0.7"> LGBM</mark>**

# %%
lgbm = LGBMRegressor()
param_grid = {
    'learning_rate' : [0.0001,0.001,0.01,0.1,1],
    'max_depth':range(3,21,3),
    "gamma": [i/10.0 for i in range(0,5)],
    "colsample_bytree": [i/10.0 for i in range(3,10)],
    "reg_alpha": [1e-5, 1e-2, 0.1, 1, 10, 100],
    "reg_lambda": [1e-5, 1e-2, 0.1, 1, 10, 100]
    
}
lgbm_cv = RandomizedSearchCV(lgbm, param_grid, n_iter = 100, refit='recall',
         scoring='neg_mean_squared_error', cv = 5, verbose=2, random_state=42, n_jobs = -1)
lgbm_cv.fit(X_train,y_train)
# Out:
# [CV] END colsample_bytree=0.8, gamma=0.4, learning_rate=0.001, max_depth=3, reg_alpha=0.1, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.01, max_depth=15, reg_alpha=1, reg_lambda=1e-05; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.01, max_depth=15, reg_alpha=1, reg_lambda=1e-05; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.01, max_depth=15, reg_alpha=1, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.01, max_depth=15, reg_alpha=1, reg_lambda=1e-05; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.01, max_depth=15, reg_alpha=1, reg_lambda=1e-05; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=10, reg_lambda=10; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=10, reg_lambda=10; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=10, reg_lambda=10; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=10, reg_lambda=10; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=10, reg_lambda=10; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=3, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=3, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=3, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=3, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=3, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=6, reg_alpha=100, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=6, reg_alpha=100, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=6, reg_alpha=100, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=6, reg_alpha=100, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=6, reg_alpha=100, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.01, max_depth=3, reg_alpha=100, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.01, max_depth=3, reg_alpha=100, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.01, max_depth=3, reg_alpha=100, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.01, max_depth=3, reg_alpha=100, reg_lambda=1e-05; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.01, max_depth=3, reg_alpha=100, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=1, max_depth=6, reg_alpha=0.01, reg_lambda=0.01; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=1, max_depth=6, reg_alpha=0.01, reg_lambda=0.01; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=1, max_depth=6, reg_alpha=0.01, reg_lambda=0.01; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=1, max_depth=6, reg_alpha=0.01, reg_lambda=0.01; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=1, max_depth=6, reg_alpha=0.01, reg_lambda=0.01; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.0001, max_depth=15, reg_alpha=0.01, reg_lambda=0.1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.0001, max_depth=15, reg_alpha=0.01, reg_lambda=0.1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.0001, max_depth=15, reg_alpha=0.01, reg_lambda=0.1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.0001, max_depth=15, reg_alpha=0.01, reg_lambda=0.1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.0001, max_depth=15, reg_alpha=0.01, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=3, reg_alpha=0.01, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=3, reg_alpha=0.01, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=3, reg_alpha=0.01, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=3, reg_alpha=0.01, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=3, reg_alpha=0.01, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.001, max_depth=3, reg_alpha=1e-05, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.001, max_depth=3, reg_alpha=1e-05, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.001, max_depth=3, reg_alpha=1e-05, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.001, max_depth=3, reg_alpha=1e-05, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.001, max_depth=3, reg_alpha=1e-05, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.0001, max_depth=12, reg_alpha=10, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.0001, max_depth=12, reg_alpha=10, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.0001, max_depth=12, reg_alpha=10, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.0001, max_depth=12, reg_alpha=10, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.0001, max_depth=12, reg_alpha=10, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.01, max_depth=3, reg_alpha=1, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.01, max_depth=3, reg_alpha=1, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.01, max_depth=3, reg_alpha=1, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.01, max_depth=3, reg_alpha=1, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.01, max_depth=3, reg_alpha=1, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=15, reg_alpha=0.01, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=15, reg_alpha=0.01, reg_lambda=100; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=15, reg_alpha=0.01, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=15, reg_alpha=0.01, reg_lambda=100; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=15, reg_alpha=0.01, reg_lambda=100; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=1, max_depth=9, reg_alpha=1, reg_lambda=100; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=1, max_depth=9, reg_alpha=1, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=1, max_depth=9, reg_alpha=1, reg_lambda=100; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=1, max_depth=9, reg_alpha=1, reg_lambda=100; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=1, max_depth=9, reg_alpha=1, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.01, max_depth=6, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.01, max_depth=6, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.01, max_depth=6, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.01, max_depth=6, reg_alpha=100, reg_lambda=1; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.01, max_depth=6, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.001, max_depth=6, reg_alpha=10, reg_lambda=10; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.001, max_depth=6, reg_alpha=10, reg_lambda=10; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.001, max_depth=6, reg_alpha=10, reg_lambda=10; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.001, max_depth=6, reg_alpha=10, reg_lambda=10; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.001, max_depth=6, reg_alpha=10, reg_lambda=10; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=15, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=15, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=15, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=15, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=15, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=9, reg_alpha=1e-05, reg_lambda=0.01; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=9, reg_alpha=1e-05, reg_lambda=0.01; total time=   1.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=9, reg_alpha=1e-05, reg_lambda=0.01; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=9, reg_alpha=1e-05, reg_lambda=0.01; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=9, reg_alpha=1e-05, reg_lambda=0.01; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=6, reg_alpha=1, reg_lambda=0.01; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=6, reg_alpha=1, reg_lambda=0.01; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=6, reg_alpha=1, reg_lambda=0.01; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=6, reg_alpha=1, reg_lambda=0.01; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.1, max_depth=6, reg_alpha=1, reg_lambda=0.01; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.0001, max_depth=15, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.0001, max_depth=15, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.0001, max_depth=15, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.0001, max_depth=15, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.0001, max_depth=15, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.0001, max_depth=3, reg_alpha=0.1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.0001, max_depth=3, reg_alpha=0.1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.0001, max_depth=3, reg_alpha=0.1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.0001, max_depth=3, reg_alpha=0.1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.0001, max_depth=3, reg_alpha=0.1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=0.1, reg_lambda=0.01; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=0.1, reg_lambda=0.01; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=0.1, reg_lambda=0.01; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=0.1, reg_lambda=0.01; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=0.1, reg_lambda=0.01; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=18, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=18, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=18, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=18, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=18, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.01, max_depth=3, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.01, max_depth=3, reg_alpha=10, reg_lambda=0.01; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.01, max_depth=3, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.01, max_depth=3, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.01, max_depth=3, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=1, max_depth=18, reg_alpha=0.01, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=1, max_depth=18, reg_alpha=0.01, reg_lambda=0.1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=1, max_depth=18, reg_alpha=0.01, reg_lambda=0.1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=1, max_depth=18, reg_alpha=0.01, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=1, max_depth=18, reg_alpha=0.01, reg_lambda=0.1; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=15, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=15, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=15, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=15, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.001, max_depth=15, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.001, max_depth=6, reg_alpha=1, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.001, max_depth=6, reg_alpha=1, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.001, max_depth=6, reg_alpha=1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.001, max_depth=6, reg_alpha=1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.0, learning_rate=0.001, max_depth=6, reg_alpha=1, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=0.1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=0.1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=0.1, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=0.1, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=0.1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.001, max_depth=12, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.001, max_depth=12, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.001, max_depth=12, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.001, max_depth=12, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.4, learning_rate=0.001, max_depth=12, reg_alpha=1, reg_lambda=1; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=18, reg_alpha=10, reg_lambda=0.01; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=18, reg_alpha=10, reg_lambda=0.01; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=18, reg_alpha=10, reg_lambda=0.01; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=18, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=18, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.001, max_depth=6, reg_alpha=100, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.001, max_depth=6, reg_alpha=100, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.001, max_depth=6, reg_alpha=100, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.001, max_depth=6, reg_alpha=100, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.001, max_depth=6, reg_alpha=100, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.0001, max_depth=18, reg_alpha=10, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.0001, max_depth=18, reg_alpha=10, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.0001, max_depth=18, reg_alpha=10, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.0001, max_depth=18, reg_alpha=10, reg_lambda=0.1; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.0001, max_depth=18, reg_alpha=10, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=9, reg_alpha=0.1, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=9, reg_alpha=0.1, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=9, reg_alpha=0.1, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=9, reg_alpha=0.1, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.1, max_depth=9, reg_alpha=0.1, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=1, max_depth=18, reg_alpha=1e-05, reg_lambda=1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=1, max_depth=18, reg_alpha=1e-05, reg_lambda=1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=1, max_depth=18, reg_alpha=1e-05, reg_lambda=1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=1, max_depth=18, reg_alpha=1e-05, reg_lambda=1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=1, max_depth=18, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=1, max_depth=15, reg_alpha=1e-05, reg_lambda=1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=1, max_depth=15, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=1, max_depth=15, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=1, max_depth=15, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=1, max_depth=15, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=0.01, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=0.01, reg_lambda=0.1; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=0.01, reg_lambda=0.1; total time=   1.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=0.01, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=0.01, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=6, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=6, reg_alpha=10, reg_lambda=0.01; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=6, reg_alpha=10, reg_lambda=0.01; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=6, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=6, reg_alpha=10, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=9, reg_alpha=0.1, reg_lambda=1e-05; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=9, reg_alpha=0.1, reg_lambda=1e-05; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=9, reg_alpha=0.1, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=9, reg_alpha=0.1, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=9, reg_alpha=0.1, reg_lambda=1e-05; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=12, reg_alpha=10, reg_lambda=1; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=12, reg_alpha=10, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=12, reg_alpha=10, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=12, reg_alpha=10, reg_lambda=1; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=12, reg_alpha=10, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=12, reg_alpha=1e-05, reg_lambda=1e-05; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=12, reg_alpha=1e-05, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=12, reg_alpha=1e-05, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=12, reg_alpha=1e-05, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=12, reg_alpha=1e-05, reg_lambda=1e-05; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=9, reg_alpha=100, reg_lambda=1; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=9, reg_alpha=100, reg_lambda=1; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=9, reg_alpha=100, reg_lambda=1; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=9, reg_alpha=100, reg_lambda=1; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=9, reg_alpha=100, reg_lambda=1; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=1, max_depth=18, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=1, max_depth=18, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=1, max_depth=18, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=1, max_depth=18, reg_alpha=1, reg_lambda=1e-05; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.0, learning_rate=1, max_depth=18, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=18, reg_alpha=0.1, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=18, reg_alpha=0.1, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=18, reg_alpha=0.1, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=18, reg_alpha=0.1, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=18, reg_alpha=0.1, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=100, reg_lambda=0.01; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=100, reg_lambda=0.01; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=100, reg_lambda=0.01; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=100, reg_lambda=0.01; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=100, reg_lambda=0.01; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.001, max_depth=9, reg_alpha=0.1, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.001, max_depth=9, reg_alpha=0.1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.001, max_depth=9, reg_alpha=0.1, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.001, max_depth=9, reg_alpha=0.1, reg_lambda=100; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.001, max_depth=9, reg_alpha=0.1, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=15, reg_alpha=1e-05, reg_lambda=1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=15, reg_alpha=1e-05, reg_lambda=1; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=15, reg_alpha=1e-05, reg_lambda=1; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=15, reg_alpha=1e-05, reg_lambda=1; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=1, max_depth=15, reg_alpha=1e-05, reg_lambda=1; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.001, max_depth=18, reg_alpha=0.1, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.001, max_depth=18, reg_alpha=0.1, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.001, max_depth=18, reg_alpha=0.1, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.001, max_depth=18, reg_alpha=0.1, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.001, max_depth=18, reg_alpha=0.1, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=1, max_depth=9, reg_alpha=0.01, reg_lambda=100; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=1, max_depth=9, reg_alpha=0.01, reg_lambda=100; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=1, max_depth=9, reg_alpha=0.01, reg_lambda=100; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=1, max_depth=9, reg_alpha=0.01, reg_lambda=100; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=1, max_depth=9, reg_alpha=0.01, reg_lambda=100; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.01, max_depth=9, reg_alpha=100, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.01, max_depth=9, reg_alpha=100, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.01, max_depth=9, reg_alpha=100, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.01, max_depth=9, reg_alpha=100, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.01, max_depth=9, reg_alpha=100, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=1, max_depth=9, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=1, max_depth=9, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=1, max_depth=9, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=1, max_depth=9, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=1, max_depth=9, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.001, max_depth=18, reg_alpha=0.01, reg_lambda=1e-05; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.001, max_depth=18, reg_alpha=0.01, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.001, max_depth=18, reg_alpha=0.01, reg_lambda=1e-05; total time=   0.8s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.001, max_depth=18, reg_alpha=0.01, reg_lambda=1e-05; total time=   0.9s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=0.001, max_depth=18, reg_alpha=0.01, reg_lambda=1e-05; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.1, max_depth=12, reg_alpha=1e-05, reg_lambda=1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.1, max_depth=12, reg_alpha=1e-05, reg_lambda=1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.1, max_depth=12, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.1, max_depth=12, reg_alpha=1e-05, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.1, max_depth=12, reg_alpha=1e-05, reg_lambda=1; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=1, max_depth=15, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=1, max_depth=15, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=1, max_depth=15, reg_alpha=1, reg_lambda=1e-05; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=1, max_depth=15, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=1, max_depth=15, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=12, reg_alpha=100, reg_lambda=1e-05; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=12, reg_alpha=100, reg_lambda=1e-05; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=12, reg_alpha=100, reg_lambda=1e-05; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=12, reg_alpha=100, reg_lambda=1e-05; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=12, reg_alpha=100, reg_lambda=1e-05; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=100, reg_lambda=1; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=100, reg_lambda=1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=100, reg_lambda=1; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=1, max_depth=6, reg_alpha=100, reg_lambda=10; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=1, max_depth=6, reg_alpha=100, reg_lambda=10; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=1, max_depth=6, reg_alpha=100, reg_lambda=10; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=1, max_depth=6, reg_alpha=100, reg_lambda=10; total time=   0.0s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=1, max_depth=6, reg_alpha=100, reg_lambda=10; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=1, max_depth=18, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=1, max_depth=18, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=1, max_depth=18, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=1, max_depth=18, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.0, learning_rate=1, max_depth=18, reg_alpha=1, reg_lambda=1e-05; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=18, reg_alpha=1e-05, reg_lambda=10; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=18, reg_alpha=1e-05, reg_lambda=10; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=18, reg_alpha=1e-05, reg_lambda=10; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=18, reg_alpha=1e-05, reg_lambda=10; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=18, reg_alpha=1e-05, reg_lambda=10; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=0.01, reg_lambda=0.01; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=0.01, reg_lambda=0.01; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=0.01, reg_lambda=0.01; total time=   0.8s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=0.01, reg_lambda=0.01; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.001, max_depth=9, reg_alpha=0.01, reg_lambda=0.01; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.0001, max_depth=9, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.0001, max_depth=9, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.0001, max_depth=9, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.0001, max_depth=9, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.0001, max_depth=9, reg_alpha=100, reg_lambda=100; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=1, max_depth=6, reg_alpha=1, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=1, max_depth=6, reg_alpha=1, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=1, max_depth=6, reg_alpha=1, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=1, max_depth=6, reg_alpha=1, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=1, max_depth=6, reg_alpha=1, reg_lambda=0.01; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, reg_alpha=0.1, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, reg_alpha=0.1, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, reg_alpha=0.1, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, reg_alpha=0.1, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=3, reg_alpha=0.1, reg_lambda=0.1; total time=   0.2s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=10, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=10, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=10, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=10, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=1, max_depth=15, reg_alpha=10, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=1, max_depth=18, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=1, max_depth=18, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=1, max_depth=18, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=1, max_depth=18, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=1, max_depth=18, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=15, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=15, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=15, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=15, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=15, reg_alpha=1e-05, reg_lambda=0.1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=9, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=9, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=9, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=9, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=9, reg_alpha=100, reg_lambda=100; total time=   0.1s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=1, reg_lambda=1; total time=   0.7s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=1, reg_lambda=1; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.0, learning_rate=0.0001, max_depth=15, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=12, reg_alpha=1, reg_lambda=10; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=12, reg_alpha=1, reg_lambda=10; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=12, reg_alpha=1, reg_lambda=10; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=12, reg_alpha=1, reg_lambda=10; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=12, reg_alpha=1, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=0.1, reg_lambda=10; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=0.1, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=0.1, reg_lambda=10; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=0.1, reg_lambda=10; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.1, max_depth=9, reg_alpha=0.1, reg_lambda=10; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.0001, max_depth=9, reg_alpha=0.01, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.0001, max_depth=9, reg_alpha=0.01, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.0001, max_depth=9, reg_alpha=0.01, reg_lambda=10; total time=   0.3s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.0001, max_depth=9, reg_alpha=0.01, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.9, gamma=0.0, learning_rate=0.0001, max_depth=9, reg_alpha=0.01, reg_lambda=10; total time=   0.6s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=12, reg_alpha=0.01, reg_lambda=10; total time=   0.9s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=12, reg_alpha=0.01, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=12, reg_alpha=0.01, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=12, reg_alpha=0.01, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=12, reg_alpha=0.01, reg_lambda=10; total time=   0.4s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.1, max_depth=15, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.1, max_depth=15, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.1, max_depth=15, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.1, max_depth=15, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.1, max_depth=15, reg_alpha=1, reg_lambda=1; total time=   0.5s
# [LightGBM] [Warning] Unknown parameter: gamma
# RandomizedSearchCV(cv=5, estimator=LGBMRegressor(), n_iter=100, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.3, 0.4, 0.5, 0.6,
#                                                              0.7, 0.8, 0.9],
#                                         'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'learning_rate': [0.0001, 0.001, 0.01,
#                                                           0.1, 1],
#                                         'max_depth': range(3, 21, 3),
#                                         'reg_alpha': [1e-05, 0.01, 0.1, 1, 10,
#                                                       100],
#                                         'reg_lambda': [1e-05, 0.01, 0.1, 1, 10,
#                                                        100]},
#                    random_state=42, refit='recall',
#                    scoring='neg_mean_squared_error', verbose=2)

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>7.3 |</span></b> Accuracy of models after tuning </b></p></div>

# %% [markdown]
# - **<mark style="background-color:#D1D96A;color:black;border-radius:5px;opacity:0.7"> A table that shows the cross validation R2 score and RMSE after tuning</mark>**

# %%
print(' Cross validation scores of the models after tuning \n')
table = [["Model name","R2 score",'RMSE'],
        ['XGBOOST',1+xgb_cv.best_score_, -xgb_cv.best_score_],
        ['Random forest',1+rf_cv.best_score_, -rf_cv.best_score_],
        ['LGBM',1+lgbm_cv.best_score_, -lgbm_cv.best_score_],]
tab =PrettyTable(table[0])
tab.add_row(table[1])
tab.add_row(table[2])
tab.add_row(table[3])
tab.hrules = ALL
tab.vrules = ALL
print(tab)
# Out:
#  Cross validation scores of the models after tuning
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28/2423854922.py in <module>
#       1 print(' Cross validation scores of the models after tuning \n')
#       2 table = [["Model name","R2 score",'RMSE'],
# ----> 3         ['XGBOOST',1+xgb_cv.best_score_, -xgb_cv.best_score_],
#       4         ['Random forest',1+rf_cv.best_score_, -rf_cv.best_score_],
#       5         ['LGBM',1+lgbm_cv.best_score_, -lgbm_cv.best_score_],]
#
# NameError: name 'xgb_cv' is not defined

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see, all of the model accuracies improved and once again the LGBM model is the best and we use it for our final prediction and competition submission.</span>

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>4.4 |</span></b> Define the final regression model </b></p></div>

# %%
regressor = LGBMRegressor(**lgbm_cv.best_params_)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>Here we define the best model using optimized parameters based step 7.3</span>

# %% [markdown]
# # <b>8 <span style='color:#94D4F6'>|</span>Training and Testing the regression Model</b>

# %%
regressor.fit(X_train, y_train)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>Here we train the final regression model</span>

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;background-color:#03112A;font-size:150%;letter-spacing:1.0px"><p style="padding: 10px;color:white;"><b><b><span style='color:#94D4F6'>8.1 |</span></b> Testing the regression model </b></p></div>

# %%
# prediciting the value of y for the test set X_test
y_pred = regressor.predict(X_test)
# printing the predicted values and test values side by side

## we control which print only two decimal points
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# # <b>9 <span style='color:#94D4F6'>|</span> Deal with Test Data</b>

# %%
df_test.head()

# %%
df_test.shape

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see, we have 80 columns including columns which not necessary for our prediction and columns with missing data and categorical data.</span>

# %%
df_test.columns

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>As you can see, we have the 80 columns name here and we should do some preProcessing operations on our data</span>

# %% [markdown]
# - **<mark style="background-color:#D1D96A;color:black;border-radius:5px;opacity:0.7">Dealing with missing data in the test dataset</mark>**

# %%
df_test.columns[df_test.isnull().sum() > 0]

# %%
# fill missing values by previous value
df_test.fillna(method='bfill',inplace=True)
# fill missing values by next value
df_test.fillna(method='ffill',inplace=True)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>here we fill the missing Data with previous data and the next value</span>

# %% [markdown]
# - **<mark style="background-color:#D1D96A;color:black;border-radius:5px;opacity:0.7">Let's transform the dataset similar to the training set</mark>**

# %%
Id = df_test['Id'].values

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>We just need Id Columns for the submission file</span>

# %%
# Columns we should drop
new_col_drops = ['Id', 'MSSubClass', 'BsmtFinSF2', 'LowQualFinSF', 'BsmtHalfBath',
             'KitchenAbvGr', '3SsnPorch', 'MiscVal', 'ScreenPorch', 'PoolArea','YrSold', 'Utilities']
df_test.drop(new_col_drops,inplace=True,axis=1)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>We drop some columns, the same as the data set we train </span>

# %%
new_numeric_col = df_test.select_dtypes(include = np.number).columns.tolist()
new_catagorical_cols= set(df_test.columns).difference(set(new_numeric_col))
# names of columns that will label encoded
new_lecols = []
for x in new_catagorical_cols:
    new_lecols.append(x)
df_test[new_lecols] = df_test[new_lecols].apply(le.fit_transform)

# %%
#list of col  names that include numerical values
new_numeric_cols = df_test.select_dtypes(include=np.number).columns.tolist()  
df_test[new_numeric_cols] = sc_X.transform(df_test[new_numeric_cols])

# %%
X_new = df_test.iloc[:,:].values
y_new = sc_y.inverse_transform([regressor.predict(X_new)])
y_new_formatted = [ '%.0f' % elem for elem in y_new[0] ]

# %%
data = {'Id': Id, 'SalePrice': y_new_formatted }
df_sub = pd.DataFrame(data)
df_sub.head()

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>Here we were preparing a data frame for the submitted file.</span>

# %%
df_sub.to_csv('Submission.csv', index=False)

# %% [markdown]
# <span style='font-family:comic Sans MS; color:navy'>Done!</span>

# %% [markdown]
# <center>
# <span style="font-family:Comic Sans MS; color:red"><h2>Thank You😊</h2></span>
# </center>

# %% [markdown]
# # Dictionary

# %% [markdown]
# * SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# * MSSubClass: The building class
# * MSZoning: The general zoning classification
# * LotFrontage: Linear feet of street connected to property
# * LotArea: Lot size in square feet
# * Street: Type of road access
# * Alley: Type of alley access
# * LotShape: General shape of property
# * LandContour: Flatness of the property
# * Utilities: Type of utilities available
# * LotConfig: Lot configuration
# * LandSlope: Slope of property
# * Neighborhood: Physical locations within Ames city limits
# * Condition1: Proximity to main road or railroad
# * Condition2: Proximity to main road or railroad (if a second is present)
# * BldgType: Type of dwelling
# * HouseStyle: Style of dwelling
# * OverallQual: Overall material and finish quality
# * OverallCond: Overall condition rating
# * YearBuilt: Original construction date
# * YearRemodAdd: Remodel date
# * RoofStyle: Type of roof
# * RoofMatl: Roof material
# * Exterior1st: Exterior covering on house
# * Exterior2nd: Exterior covering on house (if more than one material)
# * MasVnrType: Masonry veneer type
# * MasVnrArea: Masonry veneer area in square feet
# * ExterQual: Exterior material quality
# * ExterCond: Present condition of the material on the exterior
# * Foundation: Type of foundation
# * BsmtQual: Height of the basement
# * BsmtCond: General condition of the basement
# * BsmtExposure: Walkout or garden level basement walls
# * BsmtFinType1: Quality of basement finished area
# * BsmtFinSF1: Type 1 finished square feet
# * BsmtFinType2: Quality of second finished area (if present)
# * BsmtFinSF2: Type 2 finished square feet
# * BsmtUnfSF: Unfinished square feet of basement area
# * TotalBsmtSF: Total square feet of basement area
# * Heating: Type of heating
# * HeatingQC: Heating quality and condition
# * CentralAir: Central air conditioning
# * Electrical: Electrical system
# * 1stFlrSF: First Floor square feet
# * 2ndFlrSF: Second floor square feet
# * LowQualFinSF: Low quality finished square feet (all floors)
# * GrLivArea: Above grade (ground) living area square feet
# * BsmtFullBath: Basement full bathrooms
# * BsmtHalfBath: Basement half bathrooms
# * FullBath: Full bathrooms above grade
# * HalfBath: Half baths above grade
# * Bedroom: Number of bedrooms above basement level
# * Kitchen: Number of kitchens
# * KitchenQual: Kitchen quality
# * TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# * Functional: Home functionality rating
# * Fireplaces: Number of fireplaces
# * FireplaceQu: Fireplace quality
# * GarageType: Garage location
# * GarageYrBlt: Year garage was built
# * GarageFinish: Interior finish of the garage
# * GarageCars: Size of garage in car capacity
# * GarageArea: Size of garage in square feet
# * GarageQual: Garage quality
# * GarageCond: Garage condition
# * PavedDrive: Paved driveway
# * WoodDeckSF: Wood deck area in square feet
# * OpenPorchSF: Open porch area in square feet
# * EnclosedPorch: Enclosed porch area in square feet
# * 3SsnPorch: Three season porch area in square feet
# * ScreenPorch: Screen porch area in square feet
# * PoolArea: Pool area in square feet
# * PoolQC: Pool quality
# * Fence: Fence quality
# * MiscFeature: Miscellaneous feature not covered in other categories
# * MiscVal: $Value of miscellaneous feature
# * MoSold: Month Sold
# * YrSold: Year Sold
# * SaleType: Type of sale
# * SaleCondition: Condition of sale

# %%
# plot_model(regressor)
